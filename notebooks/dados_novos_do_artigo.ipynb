# %%
import pandas as pd

# %% [markdown]
# ## Importando a primeira planilha

# %%
mmc2_sheet1 = pd.read_excel('../data/mmc2.xlsx', header=2, sheet_name=0)

# %%
mmc2_sheet1.head()
# Out:
#    Unnamed: 0 Patient_ID          Sample_ID Sample_Type  \
# 0         NaN  P-0002243  P-0002243-T01-IM3  Metastasis
# 1         NaN  P-0016608  P-0016608-T01-IM6     Primary
# 2         NaN  P-0001874  P-0001874-T01-IM3  Metastasis
# 3         NaN  P-0002297  P-0002297-T01-IM3  Metastasis
# 4         NaN  P-0008334  P-0008334-T01-IM5  Metastasis
#
#                Sample_Site Metastatic_Dz Denovo_MBC Prior_Breast_Primary  \
# 0                   Breast           Yes         No                   No
# 1  Treatment Naive Primary            No         No                   No
# 2                     Bone           Yes         No                   No
# 3                   Pleura           Yes         No                  Yes
# 4                     Bone           Yes         No                   No
#
#    Inavsaive_Carcinoma_Dx_Time  Metastatic_Recurrence_Time  ...  \
# 0                        16126                     19589.0  ...
# ...

# %%
mmc2_sheet1 = mmc2_sheet1.drop('Unnamed: 0', axis=1)

# %%
mmc2_sheet1.head()
# Out:
#   Patient_ID          Sample_ID Sample_Type              Sample_Site  \
# 0  P-0002243  P-0002243-T01-IM3  Metastasis                   Breast
# 1  P-0016608  P-0016608-T01-IM6     Primary  Treatment Naive Primary
# 2  P-0001874  P-0001874-T01-IM3  Metastasis                     Bone
# 3  P-0002297  P-0002297-T01-IM3  Metastasis                   Pleura
# 4  P-0008334  P-0008334-T01-IM5  Metastasis                     Bone
#
#   Metastatic_Dz Denovo_MBC Prior_Breast_Primary  Inavsaive_Carcinoma_Dx_Time  \
# 0           Yes         No                   No                        16126
# 1            No         No                   No                        25778
# 2           Yes         No                   No                        14383
# 3           Yes         No                  Yes                        21952
# 4           Yes         No                   No                        20347
#
#    Metastatic_Recurrence_Time  NGS_Sample_Collection_Time  ...  \
# ...

# %%
mmc2_sheet1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1918 entries, 0 to 1917
# Data columns (total 52 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Patient_ID                   1918 non-null   object
#  1   Sample_ID                    1918 non-null   object
#  2   Sample_Type                  1918 non-null   object
#  3   Sample_Site                  1918 non-null   object
#  4   Metastatic_Dz                1918 non-null   object
#  5   Denovo_MBC                   1918 non-null   object
#  6   Prior_Breast_Primary         1918 non-null   object
#  7   Inavsaive_Carcinoma_Dx_Time  1918 non-null   int64
#  8   Metastatic_Recurrence_Time   1406 non-null   float64
#  9   NGS_Sample_Collection_Time   1918 non-null   int64
#  10  Prior_Local_Recurrence       1918 non-null   object
#  11  Gender                       1918 non-null   object
#  12  Invasive_Carcinoma_Dx_Age    1918 non-null   int64
# ...

# %%
mmc2_sheet1.isnull().sum().sort_values(ascending=False)
# Out:
# Death_Time                     1496
# Metastatic_Recurrence_Time      512
# ER_Pct_Primary                   28
# OS_Event                          0
# Menopausal_Status_at_Dx           0
# M_Stage                           0
# N_Stage                           0
# T_Stage                           0
# Nuclear_Grade                     0
# Overall_Tumor_Grade               0
# Histology_Detailed                0
# Histology                         0
# Tumor_Tissue_Origin               0
# Primary_Tumor_Laterality          0
# Gender                            0
# Invasive_Carcinoma_Dx_Age         0
# Receptor_Status_Patient           0
# Prior_Local_Recurrence            0
# NGS_Sample_Collection_Time        0
# Inavsaive_Carcinoma_Dx_Time       0
# Prior_Breast_Primary              0
# Denovo_MBC                        0
# Metastatic_Dz                     0
# Sample_Site                       0
# Sample_Type                       0
# Sample_ID                         0
# ...

# %% [markdown]
# ## Importando a terceira

# %%
mmc2_sheet3 = pd.read_excel('../data/mmc2.xlsx', header=2, sheet_name=2)

# %%
mmc2_sheet3.head()
# Out:
#    Unnamed: 0 Patient_ID          Sample_ID                         Tx_Type  \
# 0         NaN  P-0000004  P-0000004-T01-IM3  Treatment - distant metastases
# 1         NaN  P-0000004  P-0000004-T01-IM3  Treatment - distant metastases
# 2         NaN  P-0000004  P-0000004-T01-IM3  Treatment - distant metastases
# 3         NaN  P-0000004  P-0000004-T01-IM3  Treatment - distant metastases
# 4         NaN  P-0000004  P-0000004-T01-IM3  Treatment - distant metastases
#
#                  Tx_Regimen  Start_Time  End_Time          Reason_Stop  \
# 0   Investigational regimen         NaN       NaN                  NaN
# 1    Fulvestrant-Exemestane     13830.0   13906.0  Disease Progression
# 2              Capecitabine     13906.0   14098.0  Disease Progression
# 3  Nab paclitaxel-Cisplatin     14134.0   14326.0             Toxicity
# 4     Everolimus-Exemestane     14326.0   14384.0  Disease Progression
#
#    Tx_Class           Tx_Class_Broad  Tx_Line  PFS_Month  PFS_Event  \
# ...

# %%
mmc2_sheet3 = mmc2_sheet3.drop('Unnamed: 0', axis=1)

# %%
mmc2_sheet3.head()
# Out:
#   Patient_ID          Sample_ID                         Tx_Type  \
# 0  P-0000004  P-0000004-T01-IM3  Treatment - distant metastases
# 1  P-0000004  P-0000004-T01-IM3  Treatment - distant metastases
# 2  P-0000004  P-0000004-T01-IM3  Treatment - distant metastases
# 3  P-0000004  P-0000004-T01-IM3  Treatment - distant metastases
# 4  P-0000004  P-0000004-T01-IM3  Treatment - distant metastases
#
#                  Tx_Regimen  Start_Time  End_Time          Reason_Stop  \
# 0   Investigational regimen         NaN       NaN                  NaN
# 1    Fulvestrant-Exemestane     13830.0   13906.0  Disease Progression
# 2              Capecitabine     13906.0   14098.0  Disease Progression
# 3  Nab paclitaxel-Cisplatin     14134.0   14326.0             Toxicity
# 4     Everolimus-Exemestane     14326.0   14384.0  Disease Progression
#
#    Tx_Class           Tx_Class_Broad  Tx_Line  PFS_Month  PFS_Event  \
# 0       NaN                      NaN      1.0        NaN        NaN
# ...

# %%
mmc2_sheet3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8792 entries, 0 to 8791
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient_ID          8792 non-null   object
#  1   Sample_ID           8792 non-null   object
#  2   Tx_Type             8792 non-null   object
#  3   Tx_Regimen          8792 non-null   object
#  4   Start_Time          7988 non-null   float64
#  5   End_Time            7988 non-null   float64
#  6   Reason_Stop         7988 non-null   object
#  7   Tx_Class            8059 non-null   object
#  8   Tx_Class_Broad      8059 non-null   object
#  9   Tx_Line             5890 non-null   float64
#  10  PFS_Month           7977 non-null   float64
#  11  PFS_Event           5176 non-null   float64
#  12  Bx_Days_From_Start  7980 non-null   float64
#  13  Bx_Days_From_End    7977 non-null   float64
#  14  Sample_Tx_Status    7980 non-null   object
# dtypes: float64(7), object(8)
# ...

# %%
mmc2_sheet3.isnull().sum().sort_values(ascending=False)
# Out:
# PFS_Event             3616
# Tx_Line               2902
# Bx_Days_From_End       815
# PFS_Month              815
# Sample_Tx_Status       812
# Bx_Days_From_Start     812
# Reason_Stop            804
# End_Time               804
# Start_Time             804
# Tx_Class_Broad         733
# Tx_Class               733
# Tx_Regimen               0
# Tx_Type                  0
# Sample_ID                0
# Patient_ID               0
# dtype: int64

# %% [markdown]
# ## Juntando os datasets do mmc2 - sheets 1 e 3

# %%
mmc2 = mmc2_sheet1.merge(mmc2_sheet3, on='Sample_ID')

# %%
mmc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8792 entries, 0 to 8791
# Data columns (total 66 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Patient_ID_x                 8792 non-null   object
#  1   Sample_ID                    8792 non-null   object
#  2   Sample_Type                  8792 non-null   object
#  3   Sample_Site                  8792 non-null   object
#  4   Metastatic_Dz                8792 non-null   object
#  5   Denovo_MBC                   8792 non-null   object
#  6   Prior_Breast_Primary         8792 non-null   object
#  7   Inavsaive_Carcinoma_Dx_Time  8792 non-null   int64
#  8   Metastatic_Recurrence_Time   8135 non-null   float64
#  9   NGS_Sample_Collection_Time   8792 non-null   int64
#  10  Prior_Local_Recurrence       8792 non-null   object
#  11  Gender                       8792 non-null   object
#  12  Invasive_Carcinoma_Dx_Age    8792 non-null   int64
# ...

# %%
# percentual de nulos por coluna
mmc2.isnull().sum().sort_values(ascending=False)[:16]/8792*100
# Out:
# Death_Time                    66.071429
# PFS_Event                     41.128298
# Tx_Line                       33.007279
# PFS_Month                      9.269791
# Bx_Days_From_End               9.269791
# Sample_Tx_Status               9.235669
# Bx_Days_From_Start             9.235669
# Reason_Stop                    9.144677
# End_Time                       9.144677
# Start_Time                     9.144677
# Tx_Class_Broad                 8.337125
# Tx_Class                       8.337125
# Metastatic_Recurrence_Time     7.472702
# ER_Pct_Primary                 1.762966
# Sample_Site                    0.000000
# Metastatic_Dz                  0.000000
# dtype: float64
